# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
yt=pd.read_csv('../../../youtube/CAvideos.csv')

# %%
yt.head(40)
# Out:
#        video_id trending_date  \
# 0   n1WpP7iowLc      17.14.11
# 1   0dBIkQ4Mz1M      17.14.11
# 2   5qpjK5DgCt4      17.14.11
# 3   d380meD0W0M      17.14.11
# 4   2Vv-BfVoq4g      17.14.11
# 5   0yIWz1XEeyc      17.14.11
# 6   _uM5kFfkhB8      17.14.11
# 7   2kyS6SvSYSE      17.14.11
# 8   JzCsM1vtn78      17.14.11
# 9   43sm-QwLcx4      17.14.11
# 10  H1KBHFXm2Bg      17.14.11
# 11  U3xLOo-CNwo      17.14.11
# 12  FyZMnhUtLfE      17.14.11
# 13  7MxiQ4v0EnE      17.14.11
# 14  LUzsOyWp9lw      17.14.11
# 15  AS9-ITLhQxo      17.14.11
# 16  gifPYwArCVQ      17.14.11
# 17  8NHA23f7LvU      17.14.11
# 18  fy-CuCzaPp8      17.14.11
# 19  kzwfHumJyYc      17.14.11
# 20  nc99ccSXST0      17.14.11
# 21  puqaWrEC7tY      17.14.11
# 22  6H3wVsceoS0      17.14.11
# 23  PRlmRnU9qts      17.14.11
# 24  ZhhXLMbZ1rQ      17.14.11
# 25  wuf2KinLxZ8      17.14.11
# 26  aVTAU_4i9AY      17.14.11
# 27  7779JdxVAg0      17.14.11
# 28  jVpp2BUtMoY      17.14.11
# 29  j67FgNEvyh8      17.14.11
# ...

# %%
pd.crosstab(yt['trending_date'],yt['category_id'])
# Out:
# category_id    1   2   10  15  17  19  20  22  23  24  25  26  27  28  29  30  \
# trending_date
# 17.01.12       12   2  12   4  14   2  10  17  21  61  25   6   6   4   1   0
# 17.02.12       16   2  17   2  15   1   6  18  26  56  22   7   4   5   0   0
# 17.03.12       14   1  18   2  11   1   7  15  22  68  18  10   4   6   0   0
# 17.04.12       14   1  18   2  12   1   8  23  18  60  17  12   6   4   0   0
# 17.05.12       10   0  12   1  14   4   8  19  22  66  18  12   4   4   2   0
# ...            ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 18.30.04        8   0  15   2  14   3   3  21  22  66  20  12   5   8   0   0
# 18.30.05       13   2  14   2  20   1   5  14  11  71  24  12   7   3   0   0
# 18.31.01        7   0  25   1  14   3   9  16  11  61  22  15   3   3   0   0
# 18.31.03       14   2  21   4  12   2   1  19  12  70  16  11   6   6   1   0
# 18.31.05        7   1  25   3  12   2   6  16  11  76  24   6   3   5   0   1
#
# ...

# %%
yt=yt.drop('description',axis=1)

# %%
yt['trending_date'].unique()
# Out:
# array(['17.14.11', '17.15.11', '17.16.11', '17.17.11', '17.18.11',
#        '17.19.11', '17.20.11', '17.21.11', '17.22.11', '17.23.11',
#        '17.24.11', '17.25.11', '17.26.11', '17.27.11', '17.28.11',
#        '17.29.11', '17.30.11', '17.01.12', '17.02.12', '17.03.12',
#        '17.04.12', '17.05.12', '17.06.12', '17.07.12', '17.08.12',
#        '17.09.12', '17.10.12', '17.11.12', '17.12.12', '17.13.12',
#        '17.14.12', '17.15.12', '17.16.12', '17.17.12', '17.18.12',
#        '17.19.12', '17.20.12', '17.21.12', '17.22.12', '17.23.12',
#        '17.24.12', '17.25.12', '17.26.12', '17.27.12', '17.28.12',
#        '17.29.12', '17.30.12', '17.31.12', '18.01.01', '18.02.01',
#        '18.03.01', '18.04.01', '18.05.01', '18.06.01', '18.07.01',
#        '18.08.01', '18.09.01', '18.12.01', '18.13.01', '18.14.01',
#        '18.15.01', '18.16.01', '18.17.01', '18.18.01', '18.19.01',
#        '18.20.01', '18.21.01', '18.22.01', '18.23.01', '18.24.01',
# ...

# %%
yt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40881 non-null  object
#  1   trending_date           40881 non-null  object
#  2   title                   40881 non-null  object
#  3   channel_title           40881 non-null  object
#  4   category_id             40881 non-null  int64
#  5   publish_time            40881 non-null  object
#  6   tags                    40881 non-null  object
#  7   views                   40881 non-null  int64
#  8   likes                   40881 non-null  int64
#  9   dislikes                40881 non-null  int64
#  10  comment_count           40881 non-null  int64
#  11  thumbnail_link          40881 non-null  object
#  12  comments_disabled       40881 non-null  bool
#  13  ratings_disabled        40881 non-null  bool
# ...

# %%
yt[yt['channel_title']=='REACT'].describe()
# Out:
#        category_id         views         likes     dislikes  comment_count  \
# count   183.000000  1.830000e+02    183.000000   183.000000     183.000000
# mean     23.934426  5.926489e+05  19044.196721   495.530055    3315.573770
# std       0.509326  3.774096e+05   9999.995495   566.186412    3425.222068
# min      20.000000  8.858500e+04   4245.000000    52.000000     732.000000
# 25%      24.000000  3.642400e+05  12327.000000   229.000000    2014.000000
# 50%      24.000000  5.181820e+05  16970.000000   365.000000    2877.000000
# 75%      24.000000  7.407305e+05  23467.500000   561.000000    3869.500000
# max      24.000000  3.422161e+06  79159.000000  5848.000000   36586.000000
#
#        views/likes
# count   183.000000
# mean     30.678122
# std       5.741588
# min      17.215593
# 25%      26.453762
# 50%      30.639181
# 75%      34.145749
# max      44.604734

# %%
yt.shape[0]/len(yt['channel_title'].unique())
# Out:
# 8.053782505910165

# %%
plt.plot(yt['views'],yt['likes'])

# %%
df=yt[(yt['likes']==0) | (yt['views']==0)].index

# %%
yt=yt.drop(index=df,axis=0)

# %%
yt['views/likes']=yt['views']/yt['likes']

# %%
df=yt.groupby(['channel_title','title','video_id'],as_index=False).agg({'views/likes':'median'}).sort_values(by='views/likes',ascending=False)
df.head(10)
# Out:
#                            channel_title  \
# 20427                       Tyson® Brand
# 23159                         tayyar.org
# 1165   Anthonys Digital Lifestyle Dotcom
# 7653                      Guardian Sport
# 23938                           感谢订阅中剧独播
# 23925                           感谢订阅中剧独播
# 21837                        Wochit News
# 16094                   Science and more
# 13561                  Paramount Network
# 20344                   Tropicana Canada
#
#                                                    title     video_id  \
# 20427                          Little Heroes of Game Day  Zcz7iPLu_5o
# 23159  بالفيديو ... سعد الحريري يتلقى معلومة من خلف ا...  SwnP04VvfOY
# 1165                  How does Yoonla work? Learning CPA  LfajgipdxmA
# 7653   Is Hungary's Elizabeth Swaney the biggest spor...  6wk0UmIAd6w
# 23938  好久不见 38 预告 | Long Time No See 38（杨子姗、郑恺、张国立、江珊...  64OiI8yb7KE
# 23925  下一站别离 35 预告 | Next time, Together forever 35（于...  m5Ro5SD2C9Q
# ...
