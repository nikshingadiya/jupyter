# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=cv2.imread("./image/n2.jpg",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img,vmin=0, vmax=255)

# %%
img.shape
# Out:
# (500, 850)

# %%
histr = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
plt.figure(figsize=(10,8))
plt.plot(histr)
