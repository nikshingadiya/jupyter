# %%
import random
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib qt

# %%
population_p = 0.5
sample = 2
size = 5
rice = []
rice1 = []
for i in range(sample):
    l1 = []
    for i in range(size):
        x = random.choice([0, 1,3])
        if(x == 1):
            l1.append(x)
        k=1.96*((population_p * (1-population_p)/size))**0.5
        print((len(l1)/size)+k,(len(l1)/size)-k)
        plt.bar((len(l1)/size)+k,(len(l1)/size)-k,color='b')
        plt.show()
#         rice.append((len(l1)/size)+k)
#         rice1.append((len(l1)/size)-k)
# Out:
# 0.6382693235899588 -0.23826932358995873
# 0.6382693235899588 -0.23826932358995873
# 0.6382693235899588 -0.23826932358995873
# 0.6382693235899588 -0.23826932358995873
# 0.6382693235899588 -0.23826932358995873
# 0.6382693235899588 -0.23826932358995873
# 0.6382693235899588 -0.23826932358995873
# 0.6382693235899588 -0.23826932358995873
# 0.8382693235899588 -0.038269323589958715
# 0.8382693235899588 -0.038269323589958715

# %%
mu = 350
sigma = 25
l1 = []
l2 = []
sample_size = 50
se = 1.96*(sigma/sample_size**0.5)
hits = 0
for i in range(1000):
    x = random.normalvariate(mu, sigma)
    l1.append(x)
    l2.append((x-se,x+se))
    plt.scatter(x-se,x+se)
