# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../../data/Car Insurance Claim Propensity/final_data.csv")

# %%
df.head(25)
# Out:
#     Break In Period  Car Age Inception  Claim Freq  \
# 0                 2                7.0           9
# 1                 3                6.0           7
# 2                 9                6.0           2
# 3                 9                6.0           7
# 4                 6                3.0           2
# 5                 1                1.0           0
# 6                 6                3.0           1
# 7                 2                2.0           2
# 8                 4                6.0           3
# 9                 4                6.0           8
# 10                2                3.0           7
# 11                1                3.0           0
# 12                0                5.0           6
# 13                0                0.0           3
# 14                6                5.0           8
# 15                2                1.0           3
# 16                6                2.0           5
# 17                2                2.0           6
# 18                3                3.0           0
# 19                1                5.0           2
# 20                5                1.0           8
# 21                5                1.0           9
# 22                0                4.0           1
# 23                4                2.0           3
# 24                3                1.0           7
#
#     Claim loss_reported_period  Claim occ_cycle                Manufacturer  \
# 0                           66               80                 Day-Shelton
# 1                           87               84                  Dennis LLC
# 2                           53               51     Smith, Waters and Adams
# 3                           47               95  Pierce, Smith and Reynolds
# 4                           99               58                Phillips PLC
# 5                            2               14            Harris-Hernandez
# 6                           50               77           Strickland-Riddle
# 7                           53               73              Hamilton Group
# 8                           10               84             Porter and Sons
# 9                           87               82            Freeman and Sons
# 10                           5               78      Rivera, Torres and Fox
# 11                          35               14                  Lawson Ltd
# 12                           8               37              Williams Group
# 13                          43               24               Moreno-Bailey
# 14                           1               26             Morgan and Sons
# 15                           9               21                  King-Hicks
# 16                          80               73      Mclean, Price and Mack
# 17                          10               61                    Neal Ltd
# 18                          23               92                  Hull-Greer
# 19                           8               13                 Dunn-Garcia
# 20                          69               62        Mack, Gray and Smith
# 21                          63               98            Contreras-Vargas
# 22                          97               50                Graham-Davis
# 23                          45               90             Mendez-Williams
# 24                          46               88    Grimes, Nguyen and Reyes
#
#              RTO City               Policy Type Marital Status  \
# 0       Lake Johnview          Our own renewals      NOT KNOWN
# 1          Heidiburgh              NCB Transfer      NOT KNOWN
# 2          East Linda          Our own renewals      NOT KNOWN
# 3          Newtonfurt              MTHF Renewal      NOT KNOWN
# 4        Michaelburgh          Our own renewals      NOT KNOWN
# 5          Knightfurt   New vehicle without NCB      NOT KNOWN
# 6      South Coryview              MTHF Renewal      NOT KNOWN
# 7            Rojaston   New vehicle without NCB      NOT KNOWN
# 8        Michaelburgh   New vehicle without NCB      NOT KNOWN
# 9           Saraville              NCB Transfer      NOT KNOWN
# 10   North Cathyville   New vehicle without NCB      NOT KNOWN
# 11         Tuckerfort   New vehicle without NCB      NOT KNOWN
# 12      East Margaret          Our own renewals      NOT KNOWN
# 13   Port Georgeville              NCB Transfer      NOT KNOWN
# 14        Michelleton          Our own renewals      NOT KNOWN
# 15  Port Melindahaven              MTHF Renewal      NOT KNOWN
# 16  South Shannontown              NCB Transfer      NOT KNOWN
# 17         Fowlerside              MTHF Renewal      NOT KNOWN
# 18       North Cheryl          Our own renewals      NOT KNOWN
# 19    West Jacqueline          Our own renewals      NOT KNOWN
# 20           Wandaton          Our own renewals      NOT KNOWN
# 4         CASHLESS     Port Christine   318840.0         OWNER DRIVER:DEATH
# 5         CASHLESS     Port Debrafort   523400.0             NET OF SALVAGE
# 6         CASHLESS        Lesliemouth   391757.0   OWNER DRIVER:BODY INJURY
# 7         CASHLESS           Boydland   662973.0         OWNER DRIVER:DEATH
# 8    REIMBURSEMENT         Rachelland   144400.0             NET OF SALVAGE
# 9              NaN      Juarezborough   472500.0             NET OF SALVAGE
# 10        CASHLESS        Gonzaleston  2238250.0   OWNER DRIVER:BODY INJURY
# 11             NaN       Bradleymouth  2238250.0   OWNER DRIVER:BODY INJURY
# 12        CASHLESS        Schmidtport   300980.0   OWNER DRIVER:BODY INJURY
# 13        CASHLESS         Sarahshire   368365.0               PARTIAL LOSS
# 14   REIMBURSEMENT        West Denise   383826.0             NET OF SALVAGE
# 15        CASHLESS        West Amyton   564758.0             NET OF SALVAGE
# 16             NaN  South Sabrinafurt   487580.0               PARTIAL LOSS
# 17        CASHLESS         East Jamie   257287.0               PARTIAL LOSS
# 18        CASHLESS          Leahhaven   303854.0   OWNER DRIVER:BODY INJURY
# 19        CASHLESS          Lopezport   751726.0   OWNER DRIVER:BODY INJURY
# 20        CASHLESS      Baileyborough   898518.0         OWNER DRIVER:DEATH
# 21        CASHLESS  West Allenborough   615970.0   OWNER DRIVER:BODY INJURY
# 22        CASHLESS         Greerhaven   332679.0   OWNER DRIVER:BODY INJURY
# 23             NaN          Woodstown   630000.0         OWNER DRIVER:DEATH
# 24        CASHLESS    South Rickyview  1035445.0   OWNER DRIVER:BODY INJURY
#
#    Claim Created Date Claim Status
# 0     2/22/2019 20:52     Rejected
# 1     10/21/2018 8:20     Rejected
# 2      1/16/2019 7:45     Rejected
# 3     12/14/2018 1:15     Rejected
# 4      12/3/2018 4:11     Accepted
# 5     1/30/2019 19:16     Accepted
# 6    10/26/2018 17:00     Rejected
# 7      1/4/2019 20:50     Accepted
# 8    10/11/2018 23:41     Rejected
# 9     2/28/2019 21:56     Rejected
# 10     12/5/2018 7:35     Rejected
# 11      1/7/2019 7:04     Rejected
# 12     11/2/2018 2:42     Rejected
# 13     3/22/2019 6:29     Rejected
# 14     1/8/2019 15:45     Accepted
# 15    12/7/2018 10:57     Accepted
# 16    1/28/2019 10:19     Rejected
# 17    11/8/2018 13:59     Accepted
# 18    12/31/2018 3:06     Rejected
# 19    2/23/2019 23:51     Rejected
# 20    3/25/2019 11:07     Accepted
# 21    10/24/2018 7:18     Accepted
# 22    1/16/2019 16:13     Accepted
# 23     2/16/2019 7:34     Rejected
# 24    2/12/2019 14:46     Rejected

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.columns
# Out:
# Index(['Break In Period', 'Car Age Inception', 'Claim Freq',
#        'Claim loss_reported_period', 'Claim occ_cycle', 'Manufacturer',
#        'RTO City', 'Policy Type', 'Marital Status', 'OCCUPATION', 'CITY',
#        'Facility Name', 'Ageny Num', 'Surveyor', 'Type Of Payment',
#        'Geography', 'IDV Value', 'Claim Element', 'Claim Created Date',
#        'Claim Status'],
#       dtype='object')

# %% [markdown]
# <ul>
#     <li><b>Break In Period:</b> A break-in period is the time between the last date for renewal of car insurance and the date on which you renew the policy. For example, your policy renewal date is January 1 and you get it renewed on January 30, then the 30-day gap in between will be known as the break-in period. Your motor policy remains inactive during this time and if your vehicle faces any damage during this period, it will not be covered under the policy.</li>
#      <br>
#     <li><b>Car Age Inception:</b>Inception refers to the actual date that an insurance policy begins. ... The policyholder will continue to have this coverage until they cancel the policy, the coverage period ceases, or the insurance company suspends coverage due to a violation of the terms of the insurance contract.</li>
#     <br>
#     <li><b>Claim Freq:</b>how many claim did by policyholder in the past </li>
#     <br>
#     <li><b>Claim loss_reported_period:</b> After the how many hour Claim reported ? means after the accident how many hours
#      take insurar for reporting this event </li>
#      <br>
#     <li><b>Claim occ_cycle:</b>occupational accident and contingent casualty period means drive injuries report time (medical report time) </li>
#      <br>
#     <li><b>Manufacturer:</b>Retailer Company</li>
#     <br>
#     <li><b>RTO City:</b>A Regional Transport Office (RTO) is an important organization in the life of a car owner. The RTO assumes significance right from the time you learn to ride a car. It is a Government agency entrusted with the responsibility of maintaining a database related to vehicles and their owners</li>
#     <br>
#     <li><b>Policy Type:</b> whcih type of policy owner take</li>
#     <br>
#     <li><b>Marital Status:</b> Owner married or not </li>
#     <br>
#     <li><b>OCCUPATION:</b>OCCUPATION </li>
#     <br>
#     <li><b>Facility Name:</b>Who is provide insurance facility?</li>
#     <br>
#     <li><b>Ageny Num:</b>Agent Number</li>
#     <br>
#     <li><b>Surveyor:</b>Who is surveyery this claim?</li>
#     <br>
#     <li><b>Geography:</b>Which place this accident or car loss?</li>
#     <br>
#     <li><b>IDV Value: If vehicle lost after then company paid </b></li>
#     <br>
#     <li><b>Claim Created Date:</b> which date claim request</li>
#     <br>
#     <li><b>Claim Status:</b>target feature </li>
#      <br>
#
#  </ul>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Break In Period             5000 non-null   int64
#  1   Car Age Inception           4995 non-null   float64
#  2   Claim Freq                  5000 non-null   int64
#  3   Claim loss_reported_period  5000 non-null   int64
#  4   Claim occ_cycle             5000 non-null   int64
#  5   Manufacturer                5000 non-null   object
#  6   RTO City                    5000 non-null   object
#  7   Policy Type                 5000 non-null   object
#  8   Marital Status              5000 non-null   object
#  9   OCCUPATION                  5000 non-null   object
#  10  CITY                        5000 non-null   object
#  11  Facility Name               5000 non-null   object
#  12  Ageny Num                   5000 non-null   int64
#  13  Surveyor                    5000 non-null   object
#  14  Type Of Payment             3649 non-null   object
#  15  Geography                   5000 non-null   object
#  16  IDV Value                   4995 non-null   float64
#  17  Claim Element               5000 non-null   object
#  18  Claim Created Date          5000 non-null   object
#  19  Claim Status                5000 non-null   object
# dtypes: float64(2), int64(5), object(13)
# memory usage: 781.4+ KB

# %%
(df['Claim Status'].value_counts()[0],df['Claim Status'].value_counts()[1])
# Out:
# (2504, 2496)

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Claim Freq", hue="Claim Status", data=df)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
