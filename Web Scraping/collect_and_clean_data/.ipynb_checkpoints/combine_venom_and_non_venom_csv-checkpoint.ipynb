# %%
import pandas as pd

# %% [markdown]
# ## venom two file combine

# %%
venom_0=pd.read_csv("./Venom/venom_data_frame_0.csv")
venom_1=pd.read_csv("./Venom/venom_data_frame_1.csv")

# %%
venom_0.head()
# Out:
#                 snake name                                  Average Venom Qty  \
# 0   Rhabdophis subminiatus  10 to 15 \xc2\xb5l ( liquid volume), Ferlan et...
# 1      Rhabdophis tigrinus  8.5 to 20. 5 mg ( dry weight ), Sakai et al (1...
# 2  Malpolon monspessulanus  0.63 \xc2\xb5l / g  body weight, Rosenberg et ...
# 3        Boiga dendrophila  B. d. multicincta : 1.0 mg ( dry weight ), Wei...
# 4       Bungarus caeruleus  8 to 20 mg ( dry weight ), U.S. Dept. Navy (19...
#
#   General: Venom Anticoagulants General: Venom Cardiotoxins  \
# 0              Possibly present                 Not present
# 1              Possibly present                 Not present
# 2                   Not present                 Not present
# 3                  Non-venomous                Non-venomous
# 4                   Not present                 Not present
#
#   General: Venom Haemorrhagins General: Venom Myotoxins  \
# 0             Possibly present              Not present
# ...

# %%
venom_1.head()
# Out:
#              snake name General: Venom Anticoagulants  \
# 0  Bungarus bungaroides                   Not present
# 1     Bungarus candidus                   Not present
# 2   Bungarus ceylonicus                   Not present
# 3    Bungarus flaviceps                   Not present
# 4      Bungarus lividus                   Not present
#
#   General: Venom Cardiotoxins General: Venom Haemorrhagins  \
# 0                 Not present                  Not present
# 1                 Not present                  Not present
# 2                 Not present                  Not present
# 3                 Not present                  Not present
# 4                 Not present                  Not present
#
#   General: Venom Myotoxins General: Venom Necrotoxins  \
# 0              Not present                Not present
# 1              Not present                Not present
# 2              Not present                Not present
# 3              Not present                Not present
# ...

# %%
venom=pd.concat([venom_0,venom_1])

# %%
venom=venom.reset_index(0,drop=True)

# %%
venom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687 entries, 0 to 686
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   snake name                     687 non-null    object
#  1   Average Venom Qty              127 non-null    object
#  2   General: Venom Anticoagulants  533 non-null    object
#  3   General: Venom Cardiotoxins    505 non-null    object
#  4   General: Venom Haemorrhagins   526 non-null    object
#  5   General: Venom Myotoxins       514 non-null    object
#  6   General: Venom Necrotoxins     512 non-null    object
#  7   General: Venom Nephrotoxins    504 non-null    object
#  8   General: Venom Neurotoxins     529 non-null    object
#  9   General: Venom Other           235 non-null    object
#  10  General: Venom Procoagulants   543 non-null    object
#  11  Preferred LD50 Estimate        19 non-null     object
# ...

# %%
venom["snake_family"]=venom["snake name"].apply(lambda x: x.split(" ")[0])

# %%
sorted(venom['snake name'].unique())
# Out:
# ['Acalyptophis peronii',
#  'Acanthophis antarcticus',
#  'Acanthophis hawkei',
#  'Acanthophis laevis',
#  'Acanthophis praelongus',
#  'Acanthophis pyrrhus',
#  'Acanthophis rugosus',
#  'Acanthophis wellsei',
#  'Adenorhinos barbouri',
#  'Agkistrodon bilineatus',
#  'Agkistrodon contortrix',
#  'Agkistrodon piscivorus',
#  'Agkistrodon taylori',
#  'Aipysurus apraefrontalis',
#  'Aipysurus duboisii',
#  'Aipysurus eydouxii',
#  'Aipysurus foliosquama',
#  'Aipysurus fuscus',
#  'Aipysurus laevis',
#  'Aipysurus pooleorum',
#  'Aipysurus tenuis',
#  'Antairoserpens warro',
#  'Aspidelaps lubricus',
#  'Aspidelaps scutatus',
#  'Aspidomorphus lineaticollis',
#  'Aspidomorphus muelleri',
#  'Aspidomorphus schlegeli',
#  'Astrotia stokesii',
#  'Atheris acuminata',
#  'Atheris broadleyi',
#  'Atheris ceratophora',
#  'Atheris chloroechis',
#  'Atheris desaixi',
#  'Atheris hirsuta',
#  'Atheris hispida',
#  'Atheris katangensis',
#  'Atheris nitschei',
#  'Atheris rungweensis',
# ...

# %% [markdown]
# ## Non venom combine

# %%
non_venom_1=pd.read_csv("./Nonvenom/Non_venom_csv_1.csv")
non_venom_2=pd.read_csv("./Nonvenom/Non_venom_csv_2.csv")

# %%
non_venom=pd.concat([non_venom_1,non_venom_2])

# %%
non_venom
# Out:
#                  snake name General: Venom Anticoagulants  \
# 0    Balanophis ceylonensis                  Non-venomous
# 1         Boiga ceylonensis                  Non-venomous
# 2            Boiga forsteni                  Non-venomous
# 3        Cerberus rhynchops                  Non-venomous
# 4     Hemorrhois ravergieri                  Non-venomous
# ..                      ...                           ...
# 126  Acrochordus granulatus                   Not present
# 127   Acrochordus javanicus                   Not present
# 128         Morelia spilota                   Not present
# 129    Corallus grenadensis                   Not present
# 130          Eryx whitakeri                   Not present
#
#     General: Venom Cardiotoxins General: Venom Haemorrhagins  \
# 0                  Non-venomous                 Non-venomous
# 1                  Non-venomous                 Non-venomous
# 2                  Non-venomous                 Non-venomous
# ...

# %%
non_venom=non_venom.reset_index(0,drop=True)

# %%
non_venom
# Out:
#                   snake name General: Venom Anticoagulants  \
# 0     Balanophis ceylonensis                  Non-venomous
# 1          Boiga ceylonensis                  Non-venomous
# 2             Boiga forsteni                  Non-venomous
# 3         Cerberus rhynchops                  Non-venomous
# 4      Hemorrhois ravergieri                  Non-venomous
# ...                      ...                           ...
# 1949  Acrochordus granulatus                   Not present
# 1950   Acrochordus javanicus                   Not present
# 1951         Morelia spilota                   Not present
# 1952    Corallus grenadensis                   Not present
# 1953          Eryx whitakeri                   Not present
#
#      General: Venom Cardiotoxins General: Venom Haemorrhagins  \
# 0                   Non-venomous                 Non-venomous
# 1                   Non-venomous                 Non-venomous
# 2                   Non-venomous                 Non-venomous
# ...

# %%
non_venom["snake_family"]=non_venom["snake name"].apply(lambda x: x.split(" ")[0])

# %%
non_venom['class']=non_venom["class"].replace({"Not":0})

# %%
final
