# %%
import requests,webbrowser
from bs4  import BeautifulSoup
import time
import pandas as pd
import re 
import numpy as np

# %% [markdown]
# ## Round 1

# %%
list_1_to_500 = []
for i in range(1, 5):
    id_snake = str(i)
    length=len(id_snake)
    if length <=4:
        x = (4-length)*"0"+id_snake
        print()

        page = requests.get(
            "http://www.toxinology.com/fusebox.cfm?fuseaction=main.snakes.display&id=SN"+x)
        list_1_to_500.append(page)
        time.sleep(2)
print("done")
# Out:
# done

# %%
BeautifulSoup(list_1_to_500[0].content)
# Out:
# <html>
# <head><script src="/CFIDE/scripts/cfform.js" type="text/javascript"></script>
# <script src="/CFIDE/scripts/masks.js" type="text/javascript"></script>
# <title>WCH Clinical Toxinology Resources</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Clinical Toxinology Resources Website provides information on venoms, toxins, antivenoms, diagnosis, treatment and emergency medicine, for snakebite, spiderbite, envenoming and poisoning by animals, plants, mushrooms." name="description"/>
# <meta content="snakes, spiders, scorpions, jellyfish, cone, shells, fish, shellfish, bites, stings, venoms, envenomation, snakebite, spiderbite, toxins, poisonous, mushrooms, plants, toxinology, antivenoms, antidotes, treatment, ticks, fugu, ciguatera" name="keywords"/>
# <link href="styles/main.css" rel="stylesheet" type="text/css"/>
# <script language="JavaScript1.2" src="scripts/scr_image.js" type="text/javascript"></script>
# ...

# %%
data_1_to_500=pd.DataFrame(data=np.array(list_1_to_500),columns=["0_to_500_response"])

# %%
for i,j in enumerate(list_1_to_500):
     data_1_to_500.loc[i,"content"]=j.content

# %%
BeautifulSoup(data_1_to_500['content'][0])
# Out:
# <html>
# <head><script src="/CFIDE/scripts/cfform.js" type="text/javascript"></script>
# <script src="/CFIDE/scripts/masks.js" type="text/javascript"></script>
# <title>WCH Clinical Toxinology Resources</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Clinical Toxinology Resources Website provides information on venoms, toxins, antivenoms, diagnosis, treatment and emergency medicine, for snakebite, spiderbite, envenoming and poisoning by animals, plants, mushrooms." name="description"/>
# <meta content="snakes, spiders, scorpions, jellyfish, cone, shells, fish, shellfish, bites, stings, venoms, envenomation, snakebite, spiderbite, toxins, poisonous, mushrooms, plants, toxinology, antivenoms, antidotes, treatment, ticks, fugu, ciguatera" name="keywords"/>
# <link href="styles/main.css" rel="stylesheet" type="text/css"/>
# <script language="JavaScript1.2" src="scripts/scr_image.js" type="text/javascript"></script>
# ...

# %%
data_1_to_500.to_csv("WHC_Data.csv",index=False)

# %%
m=pd.read_csv("WHC_Data.csv")

# %%
m["content"][0]
# Out:
# 'b\'\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n<html>\\r\\n\\r\\n<head><script type="text/javascript" src="/CFIDE/scripts/cfform.js"></script>\\n<script type="text/javascript" src="/CFIDE/scripts/masks.js"></script>\\n\\r\\n\\r\\n  <title>WCH Clinical Toxinology Resources</title>\\r\\n\\r\\n  <meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">\\r\\n  \\r\\n  <meta name="description" content="Clinical Toxinology Resources Website provides information on venoms, toxins, antivenoms, diagnosis, treatment and emergency medicine, for snakebite, spiderbite, envenoming and poisoning by animals, plants, mushrooms.">\\r\\n  \\r\\n  <meta name="keywords" content="snakes, spiders, scorpions, jellyfish, cone, shells, fish, shellfish, bites, stings, venoms, envenomation, snakebite, spiderbite, toxins, poisonous, mushrooms, plants, toxinology, antivenoms, antidotes, treatment, ticks, fugu, ciguatera">\\r\\n\\r\\n  <link rel="stylesheet" href="styles/main.css" type="text/css">\\r\\n\\r
# ...

# %%
print(page.headers)
# Out:
# {'Content-Type': 'text/html;charset=UTF-8', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'Server': 'Microsoft-IIS/7.5', 'Set-Cookie': 'CFID=945315; Expires=Sun, 25-Jul-2021 16:22:25 GMT; Path=/; HttpOnly, CFTOKEN=3a548b444868a71e-7D41D64B-1A6B-4882-18B11C0B834260F6; Expires=Sun, 25-Jul-2021 16:22:25 GMT; Path=/; HttpOnly', 'X-Powered-By': 'ASP.NET', 'Date': 'Sat, 24 Jul 2021 16:22:25 GMT', 'Content-Length': '9856'}

# %%
data_1_to_500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   0_to_500_response  999 non-null    object
#  1   content            999 non-null    object
# dtypes: object(2)
# memory usage: 63.4+ KB

# %%
import sys

# %%
list_500_to_1000 = []
for i in range(500, 1000):
    id_snake = str(i)
    length=len(id_snake)
    if length <=4:
        x = (4-length)*"0"+id_snake
        page = requests.get(
            "http://www.toxinology.com/fusebox.cfm?fuseaction=main.snakes.display&id=SN"+x)
        list_500_to_1000.append(page)
        time.sleep(2)
print("done")
# Out:
# done

# %%
len(list_500_to_1000)
# Out:
# 500

# %%
list_500_to_1000
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
# ...

# %%
for i, j in enumerate(list_500_to_1000):
    data_1_to_500.loc[i+500, "0_to_500_response"] = j
    data_1_to_500.loc[i+500, "content"] = j.content

# %%
data_1_to_500
# Out:
#     0_to_500_response                                            content
# 0    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 1    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 2    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 3    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 4    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# ..                ...                                                ...
# 995  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 996  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 997  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 998  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 999  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
#
# [999 rows x 2 columns]

# %%
BeautifulSoup(list_500_to_1000[300].content)
# Out:
# <html>
# <head><script src="/CFIDE/scripts/cfform.js" type="text/javascript"></script>
# <script src="/CFIDE/scripts/masks.js" type="text/javascript"></script>
# <title>WCH Clinical Toxinology Resources</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Clinical Toxinology Resources Website provides information on venoms, toxins, antivenoms, diagnosis, treatment and emergency medicine, for snakebite, spiderbite, envenoming and poisoning by animals, plants, mushrooms." name="description"/>
# <meta content="snakes, spiders, scorpions, jellyfish, cone, shells, fish, shellfish, bites, stings, venoms, envenomation, snakebite, spiderbite, toxins, poisonous, mushrooms, plants, toxinology, antivenoms, antidotes, treatment, ticks, fugu, ciguatera" name="keywords"/>
# <link href="styles/main.css" rel="stylesheet" type="text/css"/>
# <script language="JavaScript1.2" src="scripts/scr_image.js" type="text/javascript"></script>
# ...

# %%
data_1_to_500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 499 entries, 0 to 498
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   0_to_500_response  499 non-null    object
#  1   content            499 non-null    object
# dtypes: object(2)
# memory usage: 31.7+ KB

# %%
data_1_to_500.to_csv("WHC_Data.csv",index=False)

# %% [markdown]
# ## round 2

# %%
list_1000_to_1999 = []
for i in range(1000, 1999):
    id_snake = str(i)
    length=len(id_snake)
    if length <=4:
        x = (4-length)*"0"+id_snake
        page = requests.get(
            "http://www.toxinology.com/fusebox.cfm?fuseaction=main.snakes.display&id=SN"+x)
        list_1000_to_1999.append(page)
        time.sleep(2)
    print(i)
print("done")
# Out:
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1139
# 1140
# 1141
# ...

# %%
data_1000_to_1999=pd.DataFrame(data=np.array(list_1000_to_1999),columns=["1000_to_response"])

# %%
for i, j in enumerate(list_1000_to_1999):
#     data_1000_to_1999.loc[i, "0_to_500_response"] = j
    data_1000_to_1999.loc[i, "content"] = j.content

# %%
data_1000_to_1999.rename(columns={"1000_to_response":"1000_to_1998"})
# Out:
#          1000_to_1998                                            content
# 0    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 1    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 2    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 3    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 4    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# ..                ...                                                ...
# 994  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 995  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 996  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 997  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 998  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
#
# [999 rows x 2 columns]

# %%
data_1000_to_1999.to_csv("WHC2.csv",index=False)

# %% [markdown]
# ## round 3

# %%
list_1999_to_2820 = []
for i in range(1999,2820):
    id_snake = str(i)
    length=len(id_snake)
    if length <=4:
        x = (4-length)*"0"+id_snake
        page = requests.get(
            "http://www.toxinology.com/fusebox.cfm?fuseaction=main.snakes.display&id=SN"+x)
        list_1999_to_2820.append(page)
        time.sleep(2)
    print(i)
print("done")
# Out:
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# 2051
# 2052
# 2053
# 2054
# 2055
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063
# 2064
# 2065
# 2066
# 2067
# 2068
# 2069
# 2070
# 2071
# 2072
# 2073
# 2074
# 2075
# 2076
# 2077
# 2078
# 2079
# 2080
# 2081
# 2082
# 2083
# 2084
# 2085
# 2086
# 2087
# 2088
# 2089
# 2090
# 2091
# 2092
# 2093
# 2094
# 2095
# 2096
# 2097
# 2098
# 2099
# 2100
# 2101
# 2102
# 2103
# 2104
# 2105
# 2106
# 2107
# 2108
# 2109
# 2110
# 2111
# 2112
# 2113
# 2114
# 2115
# 2116
# 2117
# 2118
# 2119
# 2120
# 2121
# 2122
# 2123
# 2124
# 2125
# 2126
# 2127
# 2128
# 2129
# 2130
# 2131
# 2132
# 2133
# 2134
# 2135
# 2136
# 2137
# 2138
# 2139
# 2140
# ...

# %%
len(list_1999_to_2820)
# Out:
# 821

# %%
2820-1999
# Out:
# 821

# %%
data_1999_to_2820=pd.DataFrame(data=np.array(list_1999_to_2820),columns=["1999_to_2820"])

# %%
for i, j in enumerate(list_1999_to_2820):
#     data_1000_to_1999.loc[i, "0_to_500_response"] = j
    data_1999_to_2820.loc[i, "content"] = j.content

# %%
data_1999_to_2820.to_csv("WHC3.csv",index=False)

# %% [markdown]
# ## Round 4 merge all data

# %%
df1=pd.read_csv("WHC_Data.csv")
df2=pd.read_csv("WHC2.csv")
df3=pd.read_csv("WHC3.csv")

# %%
df1=df1.rename(columns={"0_to_500_response":"response"})
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 998
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   0_to_500_response  999 non-null    object
#  1   content            999 non-null    object
# dtypes: object(2)
# memory usage: 23.4+ KB

# %%
df1
# Out:
#              response                                            content
# 0    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 1    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 2    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 3    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 4    <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# ..                ...                                                ...
# 994  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 995  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 996  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 997  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
# 998  <Response [200]>  b'\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n\r\n<head>...
#
# [999 rows x 2 columns]

# %%
df2=df2.rename(columns={"1000_to_response":"response"})
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   response  999 non-null    object
#  1   content   999 non-null    object
# dtypes: object(2)
# memory usage: 15.7+ KB

# %%
df3=df3.rename(columns={"1999_to_2820":"response"})
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821 entries, 0 to 820
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   response  821 non-null    object
#  1   content   821 non-null    object
# dtypes: object(2)
# memory usage: 13.0+ KB

# %%
df_final=pd.concat([df1,df2,df3],ignore_index=True)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2819 entries, 0 to 2818
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   response  2819 non-null   object
#  1   content   2819 non-null   object
# dtypes: object(2)
# memory usage: 44.2+ KB

# %%
df_final.to_csv("Final_WHC.csv",index=False)
