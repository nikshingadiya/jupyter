# %%
#Libray import 
import cv2
import numpy as np 
# import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
img1_BGR=cv2.imread("./50th_image_key/key_98.jpg")

img1_hsv=cv2.cvtColor(img1_BGR,cv2.COLOR_BGR2HSV)
img1_RGB=cv2.cvtColor(img1_BGR,cv2.COLOR_BGR2RGB)
img1_GRAY=cv2.cvtColor(img1_BGR,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img1_RGB)

# %%
img2_BGR=cv2.imread("./50th_image_key/key_147.jpg")

img2_hsv=cv2.cvtColor(img2_BGR,cv2.COLOR_BGR2HSV)
img2_RGB=cv2.cvtColor(img2_BGR,cv2.COLOR_BGR2RGB)
img2_GRAY=cv2.cvtColor(img2_BGR,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img2_RGB)
plt.savefig("img2_RGB")

# %%
img3_hsv=cv2.subtract(img2_RGB,img1_RGB)

# %%
img3_bitwise_sub=cv2.(img2_hsv,img1_hsv)
# img3=cv2.cvtColor(img3_hsv,cv2.COLOR_BGR2HSV_FULL)
img3_RGB=cv2.cvtColor(img3_hsv,cv2.COLOR_HSV2RGB)
# img3_BGR=cv2.cvtColor(img3_hsv,cv2.COLOR_HSV2BGR)
# img3_GRAY=cv2.cvtColor(img3_BGR,cv2.COLOR_BGR2GRAY)
plt.imshow(img3_hsv)

# %%
img_4=cv2.add(img3_RGB,img1_RGB)
img_4_RGB=cv2.cvtColor(img_4,cv2.COLOR_HSV2RGB)
plt.imshow(img_4)
